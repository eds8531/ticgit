# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://www.examword.com/toefl-list/5000-vocabulary-1?la=en')

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n\r\n<html>\r\n<head id="Head1"><title>\r\n\tTOEFL Vocabulary Level 1 - 1: Word List\r\n</title><meta http-equiv="content-type" content="text/html, charset=utf-8" /><meta http-equiv="content-language" content="en" /><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" /><meta name="apple-mobile-web-app-capable" content="yes" /><meta name="HandheldFriendly" content="true" /><meta name="revisit-after" content="5 days" /><meta name="classification" content="Education English Test" /><meta name="resource-type" content="document" /><meta name="distribution" content="global" /><meta name="author" content="www.examword.com" /><meta name="rating" content="GENERAL" /><meta id="meta_description" name="description" content="A proven TOEFL vocabulary list of 5000 words, learn and review the vocabulary in an efficient way, with various online and offline methods." /><meta id="meta_keywords" name="keywords" content="TOEFL vocabulary l
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head id="Head1"><title>
# 	TOEFL Vocabulary Level 1 - 1: Word List
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head id="Head1">
#   <title>
#    TOEFL Vocabulary Level 1 - 1: Word List
#   </title>
#   <meta content="text/html, charset=utf-8" http-equiv="content-type"/>
#   <meta content="en" http-equiv="content-language"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="5 days" name="revisit-after"/>
#   <meta content="Education English Test" name="classification"/>
#   <meta content="document" name="resource-type"/>
#   <meta content="global" name="distribution"/>
#   <meta content="www.examword.com" name="author"/>
#   <meta content="GENERAL" name="rating"/>
#   <meta content="A proven TOEFL vocabulary list of 5000 words, learn and review the vocabulary in an efficient way, with various online and offline methods." id="meta_description" name="description"/>
# ...

# %%
list(soup.children)
# Out:
# ['\n',
#  'html',
#  '\n',
#  <html>
#  <head id="Head1"><title>
#  	TOEFL Vocabulary Level 1 - 1: Word List
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[3]

# %%
list(html.children)
# Out:
# ['\n',
#  <head id="Head1"><title>
#  	TOEFL Vocabulary Level 1 - 1: Word List
# ...

# %%
body = list(html.children)[3]

# %%
for i in list(body.children):
    print(len(i))
# Out:
# 1
# 5
# 1
# 9
# 1
# 0
# 1
# 0
# 1
# 0
# 1
# 57
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 0
# 1

# %%
body = list(body.children)[3]

# %%
for i in list(body.children):
    print(len(i))
# Out:
# 1
# 7
# 1
# 3
# 1
# 7
# 1
# 3
# 1

# %%
body = list(body.children)[5]

# %%
for i in list(body.children):
    print(len(i))
# Out:
# 1
# 7
# 1
# 9
# 1
# 7
# 1

# %%
body = list(body.children)[3]

# %%
for i in list(body.children):
    print(len(i))
# Out:
# 1
# 3
# 1
# 0
# 1
# 0
# 1
# 0
# 1

# %%
body = list(body.children)[1]

# %%
for i in list(body.children):
    print(len(i))
# Out:
# 1
# 23
# 6

# %%
body = list(body.children)[2]

# %%
for i in list(body.children):
    print(len(i))
# Out:
# 1
# 2
# 301
# 0
# 2
# 5400

# %%
body = list(body.children)[2]

# %%
for i in list(body.children):
    print(str(i)[81:-6])
# Out:
# ew all words of the list      <button class="btn btn-xs btn-warning" onclick='zoomChanged("+"); return false; ' type="button"><img alt="Zoom In" src="../pic/icon/zoomin32gray.png" style="width:18px;height:18px;" title="Zoom In"/></button>   <button class="btn btn-xs btn-warning" onclick='zoomChanged("-"); return false; ' type="button"><img alt="Zoom Out" src="../pic/icon/zoomout32gray.png" style="width:18px;height:18px;" title="Zoom Out"/></button>
# bbreviation
# bnormal
# bort
# brasive
# bsence
# bsolutely
# bstract
# ccidental
# ccompany
# ccomplished
# accounting
# acid
# acidic
# actual
# acupuncture
# adequate
# adhere
# adhesive
# adjunct
# admit
# adventure
# adventurous
# adversity
# advocate
# aerodynamics
# affected
# affective
# aggravate
# aggregation
# ailment
# aircraft
# alert
# alike
# allegation
# alliteration
# alone
# alteration
# alternation
# aluminum
# amazement
# ambivalence
# amenable
# analogy
# analysis
# anecdote
# anesthetic
# angular
# annually
# ...

# %%
len('<div class="glface" id="t_5000-vocabulary-1_41" onclick="return glfclick(this);">')
# Out:
# 81
