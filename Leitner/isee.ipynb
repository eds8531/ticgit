# %%
import pandas as pd
import numpy as np
import openpyxl
from datetime import date, timedelta

# %%
filename = '/Users/ericschlosser/Desktop/TheHardWay/projects/Leitner/ISEEWords1 3 copy.xlsx'

df = pd.read_excel(filename)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Word               499 non-null    object
#  1   Definition         499 non-null    object
#  2   Date               0 non-null      datetime64[ns]
#  3   Consecutive Right  0 non-null      float64
#  4   Card Used          0 non-null      float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 19.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Word               499 non-null    object
#  1   Definition         499 non-null    object
#  2   Date               499 non-null    object
#  3   Consecutive Right  0 non-null      float64
#  4   Card Used          0 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 19.6+ KB

# %%
df['Word'] = df['Word'].astype(str)

# %%
df.head()
# Out:
#           Word                                Definition Date  \
# 0      abandon  leave someone who needs or counts on you  New
# 1        Abate        become less in amount or intensity  New
# 2     abdicate      give up power, duties or obligations  New
# 3  abduct (v.)                              - to kidnap   New
# 4   abase (v.)             - to lower, demean, degrade 🗑  New
#
#    Consecutive Right  Card Used
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN

# %%
df['Definition'][4:] = df['Definition'][4:].str[:-2]
# Out:
# /Users/ericschlosser/opt/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#           Word                                Definition Date  \
# 0      abandon  leave someone who needs or counts on you  New
# 1        Abate        become less in amount or intensity  New
# 2     abdicate      give up power, duties or obligations  New
# 3  abduct (v.)                              - to kidnap   New
# 4   abase (v.)               - to lower, demean, degrade  New
#
#    Consecutive Right  Card Used
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN

# %%
df['Definition'][3:] = df['Definition'][3:].str[2:]
# Out:
# /Users/ericschlosser/opt/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(10)
# Out:
#               Word                                Definition Date  \
# 0          abandon  leave someone who needs or counts on you  New
# 1            Abate        become less in amount or intensity  New
# 2         abdicate      give up power, duties or obligations  New
# 3      abduct (v.)                                to kidnap   New
# 4       abase (v.)                 to lower, demean, degrade  New
# 5     abscond (v.)                    to sneak away and hide  New
# 6       abate (v.)          to lessen, to reduce in severity  New
# 7  abbreviate (v.)                        to shorten, reduce  New
# 8  abundant (adj.)                          in great numbers  New
# 9      accede (v.)                                  to agree  New
#
#    Consecutive Right  Card Used
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
# 5                NaN        NaN
# 6                NaN        NaN
# 7                NaN        NaN
# 8                NaN        NaN
# 9                NaN        NaN

# %%
df.to_csv('isee_csv.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Word               499 non-null    object
#  1   Definition         499 non-null    object
#  2   Date               499 non-null    object
#  3   Consecutive Right  0 non-null      float64
#  4   Card Used          0 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 19.6+ KB

# %%
df['Date'] = df['Date'].replace('New', np.nan)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#           Word                                Definition Date  \
# 0      abandon  leave someone who needs or counts on you  NaT
# 1        Abate        become less in amount or intensity  NaT
# 2     abdicate      give up power, duties or obligations  NaT
# 3  abduct (v.)                                to kidnap   NaT
# 4   abase (v.)                 to lower, demean, degrade  NaT
#
#    Consecutive Right  Card Used
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN

# %%
def random_dates(start, end, n=10):

    start_u = start.value//10**9
    end_u = end.value//10**9

    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit='s')

# %%
start = pd.to_datetime('2022-10-25')
end =  pd.to_datetime('2023-10-25')
dlist = list(random_dates(start,end, 300)) + [pd.NaT]*199
df['Date'] = dlist
df['Date'] = df['Date'].dt.round('D')

# %%
df.head()
# Out:
#           Word                                Definition       Date  \
# 0      abandon  leave someone who needs or counts on you 2022-11-24
# 1        Abate        become less in amount or intensity 2023-02-08
# 2     abdicate      give up power, duties or obligations 2023-07-30
# 3  abduct (v.)                                to kidnap  2022-12-19
# 4   abase (v.)                 to lower, demean, degrade 2022-12-02
#
#    Consecutive Right  Card Used
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN

# %%
df.sort_values('Date')
# Out:
#                   Word                               Definition       Date  \
# 163         erect (v.)                   to construct, to raise 2022-10-25
# 52          atone (v.)                to apologize, make amends 2022-10-29
# 268  loquacious (adj.)                                talkative 2022-10-30
# 51        assuage (v.)                          to ease, pacify 2022-11-01
# 224    illusory (adj.)       deceptive, produced by an illusion 2022-11-01
# ..                 ...                                      ...        ...
# 494           wax (v.)  to increase gradually in size or degree        NaT
# 495       weather (v.)      to withstand or survive a situation        NaT
# 496          whet (v.)             to make more keen, stimulate        NaT
# 497     winsome (adj.)                     charming, attractive        NaT
# 498     Zeitgeist (n.)                     the spirit of the ti        NaT
#
#      Consecutive Right  Card Used
# 163                NaN        NaN
# 52                 NaN        NaN
# 268                NaN        NaN
# 51                 NaN        NaN
# 224                NaN        NaN
# ..                 ...        ...
# 494                NaN        NaN
# 495                NaN        NaN
# 496                NaN        NaN
# 497                NaN        NaN
# 498                NaN        NaN
#
# [499 rows x 5 columns]

# %%
df_today = df[df['Date'] <= str(date.today())]

# %%
date.today() + timedelta(days = 1)
# Out:
# datetime.date(2022, 10, 27)

# %%
today = date.today()
print(today)
# Out:
# 2022-10-26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Word               499 non-null    object
#  1   Definition         499 non-null    object
#  2   Date               300 non-null    datetime64[ns]
#  3   Consecutive Right  0 non-null      float64
#  4   Card Used          0 non-null      float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 19.6+ KB

# %%
words_a_day = 20
def todays_list():
    today = date.today()
    df_today = df[df['Date'] < str(date.today()+ timedelta(days = 20))]
    if df_today.shape[0] < words_a_day:
        new_words = words_a_day - df_today.shape[0]
        df_new = df[df['Date'].isnull()].iloc[:20,:]
        df_today = pd.concat([df_today, df_new], axis = 0)
    return df_today

# %%
df_today = todays_list()
df_today
# Out:
#                   Word                                         Definition  \
# 16        abridge (v.)                               to shorten, cut down
# 31          allay (v.)                                     sooth, assuage
# 51        assuage (v.)                                    to ease, pacify
# 52          atone (v.)                          to apologize, make amends
# 163         erect (v.)                             to construct, to raise
# 210  gregarious (adj.)                                 sociable, outgoing
# 224    illusory (adj.)                 deceptive, produced by an illusion
# 260   lethargic (adj.)                         sluggish, weary, apathetic
# 268  loquacious (adj.)                                          talkative
# 273  malevolent (adj.)                       having intent to harm others
# 300      myopic (adj.)                                      short-sighted
# 301      myriad (adj.)                  consisting of a very great number
# 302       narrate (v.)                                    to tell a story
# 303    nebulous (adj.)                                   indistinct, hazy
# 304   nefarious (adj.)                                horribly villainous
# 305     neologism (n.)           the creation of new words, or a new word
# 306       neonate (n.)                                     a newborn baby
# 307     noisome (adj.)  foul, offensive, particularly to the sense of ...
# 308     notoriety (n.)                        infamy, known in bad regard
# 309       novel (adj.)              strikingly new, unusual, or different
# 310     noxious (adj.)                                     harmful, toxic
# 311    obdurate (adj.)       unyielding to persuasion or moral influences
# 312     obfuscate (v.)                         to render incomprehensible
# 313  obsequious (adj.)                excessively compliant or submissive
# 314      odious (adj.)                        meriting strong displeasure
# 315   officious (adj.)                  offering unwanted help or service
# 316   olfactory (adj.)                     relating to the sense of smell
# 317     ominous (adj.)       foreboding or foreshadowing evil, portentous
# 318       oration (n.)                      a dignified and formal speech
# 319     ostracize (v.)                        to exclude from a community
#
#           Date  Consecutive Right  Card Used
# 16  2022-11-13                NaN        NaN
# 31  2022-11-02                NaN        NaN
# 51  2022-11-01                NaN        NaN
# 52  2022-10-29                NaN        NaN
# 163 2022-10-25                NaN        NaN
# 210 2022-11-08                NaN        NaN
# 224 2022-11-01                NaN        NaN
# 260 2022-11-05                NaN        NaN
# 268 2022-10-30                NaN        NaN
# 273 2022-11-09                NaN        NaN
# 300        NaT                NaN        NaN
# 301        NaT                NaN        NaN
# 302        NaT                NaN        NaN
# 303        NaT                NaN        NaN
# 304        NaT                NaN        NaN
# 305        NaT                NaN        NaN
# 306        NaT                NaN        NaN
# 307        NaT                NaN        NaN
# 308        NaT                NaN        NaN
# 309        NaT                NaN        NaN
# 310        NaT                NaN        NaN
# 311        NaT                NaN        NaN
# 312        NaT                NaN        NaN
# 313        NaT                NaN        NaN
# 314        NaT                NaN        NaN
# 315        NaT                NaN        NaN
# 316        NaT                NaN        NaN
# 317        NaT                NaN        NaN
# 318        NaT                NaN        NaN
# 319        NaT                NaN        NaN

# %%
df.to_csv('isee_csv.csv', index = False)

# %%
df = pd.read_csv('isee_csv.csv')

# %%
todays_list()
# Out:
#                   Word                                         Definition  \
# 16        abridge (v.)                               to shorten, cut down
# 31          allay (v.)                                     sooth, assuage
# 51        assuage (v.)                                    to ease, pacify
# 52          atone (v.)                          to apologize, make amends
# 163         erect (v.)                             to construct, to raise
# 210  gregarious (adj.)                                 sociable, outgoing
# 224    illusory (adj.)                 deceptive, produced by an illusion
# 260   lethargic (adj.)                         sluggish, weary, apathetic
# 268  loquacious (adj.)                                          talkative
# 273  malevolent (adj.)                       having intent to harm others
# 300      myopic (adj.)                                      short-sighted
# 301      myriad (adj.)                  consisting of a very great number
# 302       narrate (v.)                                    to tell a story
# 303    nebulous (adj.)                                   indistinct, hazy
# 304   nefarious (adj.)                                horribly villainous
# 305     neologism (n.)           the creation of new words, or a new word
# 306       neonate (n.)                                     a newborn baby
# 307     noisome (adj.)  foul, offensive, particularly to the sense of ...
# 308     notoriety (n.)                        infamy, known in bad regard
# 309       novel (adj.)              strikingly new, unusual, or different
# 310     noxious (adj.)                                     harmful, toxic
# 311    obdurate (adj.)       unyielding to persuasion or moral influences
# 312     obfuscate (v.)                         to render incomprehensible
# 313  obsequious (adj.)                excessively compliant or submissive
# 314      odious (adj.)                        meriting strong displeasure
# 315   officious (adj.)                  offering unwanted help or service
# 316   olfactory (adj.)                     relating to the sense of smell
# 317     ominous (adj.)       foreboding or foreshadowing evil, portentous
# 318       oration (n.)                      a dignified and formal speech
# 319     ostracize (v.)                        to exclude from a community
#
#            Date  Consecutive Right  Card Used
# 16   2022-11-13                NaN        NaN
# 31   2022-11-02                NaN        NaN
# 51   2022-11-01                NaN        NaN
# 52   2022-10-29                NaN        NaN
# 163  2022-10-25                NaN        NaN
# 210  2022-11-08                NaN        NaN
# 224  2022-11-01                NaN        NaN
# 260  2022-11-05                NaN        NaN
# 268  2022-10-30                NaN        NaN
# 273  2022-11-09                NaN        NaN
# 300         NaN                NaN        NaN
# 301         NaN                NaN        NaN
# 302         NaN                NaN        NaN
# 303         NaN                NaN        NaN
# 304         NaN                NaN        NaN
# 305         NaN                NaN        NaN
# 306         NaN                NaN        NaN
# 307         NaN                NaN        NaN
# 308         NaN                NaN        NaN
# 309         NaN                NaN        NaN
# 310         NaN                NaN        NaN
# 311         NaN                NaN        NaN
# 312         NaN                NaN        NaN
# 313         NaN                NaN        NaN
# 314         NaN                NaN        NaN
# 315         NaN                NaN        NaN
# 316         NaN                NaN        NaN
# 317         NaN                NaN        NaN
# 318         NaN                NaN        NaN
# 319         NaN                NaN        NaN

# %%
def print_list():
    df_today = todays_list()
    print("\n\n\nLIST OF TODAY'S WORDS\n\n\n")
    row_item = "{:25}: {:60}"

    for index, row in df_today.iterrows():
        print(row_item.format(row[0], row[1]))

# %%
print_list()
# Out:
# LIST OF TODAY'S WORDS
#
#
#
# abridge (v.)             : to shorten, cut down
# allay (v.)               :  sooth, assuage
# assuage (v.)             : to ease, pacify
# atone (v.)               : to apologize, make amends
# erect (v.)               : to construct, to raise
# gregarious (adj.)        : sociable, outgoing
# illusory (adj.)          : deceptive, produced by an illusion
# lethargic (adj.)         : sluggish, weary, apathetic
# loquacious (adj.)        : talkative
# malevolent (adj.)        : having intent to harm others
# myopic (adj.)            : short-sighted
# myriad (adj.)            : consisting of a very great number
# narrate (v.)             : to tell a story
# nebulous (adj.)          : indistinct, hazy
# nefarious (adj.)         : horribly villainous
# neologism (n.)           : the creation of new words, or a new word
# neonate (n.)             : a newborn baby
# noisome (adj.)           : foul, offensive, particularly to the sense of smell
# notoriety (n.)           : infamy, known in bad regard
# novel (adj.)             : strikingly new, unusual, or different
# noxious (adj.)           : harmful, toxic
# obdurate (adj.)          : unyielding to persuasion or moral influences
# obfuscate (v.)           : to render incomprehensible
# obsequious (adj.)        : excessively compliant or submissive
# odious (adj.)            : meriting strong displeasure
# officious (adj.)         : offering unwanted help or service
# olfactory (adj.)         : relating to the sense of smell
# ominous (adj.)           : foreboding or foreshadowing evil, portentous
# oration (n.)             : a dignified and formal speech
# ostracize (v.)           : to exclude from a community

# %%
def fc():

# %%
df_dict = df.set_index('Word').T.to_dict('list')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xm/ghz1xdl95rl7rdw7xm1jrklw0000gn/T/ipykernel_53911/1543860022.py in <module>
# ----> 1 df_dict = df.set_index('Word').T.to_list('list')
#
# ~/opt/anaconda3/envs/ML/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_list'

# %%
count = 0

for index, row in df_today.iterrows():
    if count < 1:
        print(row)
    count +=1
# Out:
# Word                         abridge (v.)
# Definition           to shorten, cut down
# Date                  2022-11-13 00:00:00
# Consecutive Right                     NaN
# Card Used                             NaN
# Name: 16, dtype: object

# %%
def to_cardlist(df_today):
    word_list_today = []
    for index, row in df_today.iterrows():
        wordcard = {}
        wordcard['index'] = index
        wordcard['word'] = row[0]
        wordcard['definition'] = row[1]
        wordcard['date'] = row[2]
        wordcard['consecutive right'] = row[3]
        wordcard['card used'] = row[4]
        word_list_today.append(wordcard)
    return word_list_today

to_cardlist(df_today)
len(to_cardlist(df_today))
# Out:
# 30

# %%
def fc():
    df = pd.read_csv('isee_csv.csv')
    word_list_future = []
    word_list_today = to_cardlist(df_today)
    while len(word_list_today) > 0:
        print(word_list_today[0]['word'] + '\n\n')
        answer = input('Enter definition: ')
        print('\n\n' + word_list_today[0]['definition'] + '\n\n')
        card = word_list_today.pop(0)
        correct = input(' Did you get the question right or wrong or have you mastered the concept (type r, w, m or q)? ')
        if correct[0].lower() == 'r':
            if card['card used'] == 0:
                card['card used'] += 1
                card['consecutive right'] += 1
                df.iloc[index]['Date'] = date.today(
                ) + timedelta(days=card['consecutive right'] * 2)
            word_list_today.append(card)
        if correct[0].lower() == 'm':
            if card['card used'] == 0:
                card['card used'] +=1
                card['consecutive right'] +=1
                df.iloc[index]['Date'] = date.today(
                ) + timedelta(days=card['consecutive right'] * 2)
            word_list_future.append(card)
        if correct[0].lower() == 'w':
            if card['card used'] == 0:
                card['card used'] += 1
                card['consecutive right'] = 1
                df.iloc[index]['Date'] = date.today() + timedelta(days=1)
            word_list_today.append(card)
        if correct[0].lower() == 'q':
            break
    df.to_csv('isee_csv.csv', index = False)

# %%
def fc():
    df = pd.read_csv('isee_csv.csv')
    word_list_future = []
    word_list_today = to_cardlist(df_today)
    while len(word_list_today) > 0:
        print(word_list_today[0]['word'] + '\n\n')
        answer = input('Enter definition: ')
        print('\n\n' + word_list_today[0]['definition'] + '\n\n')
        card = word_list_today.pop(0)
        correct = input(
            ' Did you get the question right or wrong or have you mastered the concept (type r, w, m or q)? ')
        if correct[0].lower() == 'r':
            if card['card used'] == 0:
                card['card used'] += 1
                card['consecutive right'] += 1
                df.at[card['index'], 'Date'] = date.today(
                ) + timedelta(days=card['consecutive right'] * 2)
            word_list_today.append(card)
        if correct[0].lower() == 'm':
            if card['card used'] == 0:
                card['card used'] += 1
                card['consecutive right'] += 1
                df.at[card['index'], 'Date'] = date.today(
                ) + timedelta(days=card['consecutive right'] * 2)
            word_list_future.append(card)
        if correct[0].lower() == 'w':
            if card['card used'] == 0:
                card['card used'] += 1
                card['consecutive right'] = 1
                df.at[card['index'], 'Date'] = date.today() + timedelta(days=1)
            word_list_today.append(card)
        if correct[0].lower() == 'q':
            break
    df.to_csv('isee_csv.csv', index=False)

fc()
# Out:
# abridge (v.)
#
#
#
#
# to shorten, cut down
#
#
# allay (v.)
#
#
#
#
#  sooth, assuage
#
#
# assuage (v.)
#
#
#
#
# to ease, pacify
#
#
# atone (v.)
#
#
#
#
# to apologize, make amends
#
#
# erect (v.)
#
#
#
#
# to construct, to raise
#
#
# gregarious (adj.)
#
#
#
#
# sociable, outgoing
#
#
# illusory (adj.)
#
#
#
#
# deceptive, produced by an illusion
#
#
# lethargic (adj.)
#
#
#
#
# sluggish, weary, apathetic
#
#
# loquacious (adj.)
#
#
#
#
# talkative
#
#
# malevolent (adj.)
#
#
#
#
# having intent to harm others
#
#
# myopic (adj.)
#
#
#
#
# short-sighted
#
#
# myriad (adj.)
#
#
#
#
# consisting of a very great number
#
#
# narrate (v.)
#
#
#
#
# to tell a story
#
#
# nebulous (adj.)
#
#
#
#
# indistinct, hazy
#
#
# nefarious (adj.)
#
#
#
#
# horribly villainous
#
#
# neologism (n.)
#
#
#
#
# the creation of new words, or a new word
#
#
# neonate (n.)
#
#
#
#
# a newborn baby
#
#
# noisome (adj.)
#
#
#
#
# foul, offensive, particularly to the sense of smell
#
#
# notoriety (n.)
#
#
#
#
# infamy, known in bad regard
#
#
# novel (adj.)
#
#
#
#
# strikingly new, unusual, or different
#
#
# noxious (adj.)
#
#
#
#
# harmful, toxic
#
#
# obdurate (adj.)
#
#
#
#
# unyielding to persuasion or moral influences
#
#
# obfuscate (v.)
#
#
#
#
# to render incomprehensible
#
#
# obsequious (adj.)
#
#
#
#
# excessively compliant or submissive
#
#
# odious (adj.)
#
#
#
#
# meriting strong displeasure
#
#
# officious (adj.)
#
#
#
#
# offering unwanted help or service
#
#
# olfactory (adj.)
#
#
#
#
# relating to the sense of smell
#
#
# ominous (adj.)
#
#
#
#
# foreboding or foreshadowing evil, portentous
#
#
# oration (n.)
#
#
#
#
# a dignified and formal speech
#
#
# ostracize (v.)
#
#
#
#
# to exclude from a community
#
#
# abridge (v.)
#
#
#
#
# to shorten, cut down
#
#
# allay (v.)
#
#
#
#
#  sooth, assuage

# %%
df.at[311,'Definition'] = 'Ruttiger'

# %%
df.iloc[311]['Definition']
# Out:
# 'Ruttiger'

# %%
df['Date'] = [pd.NaT]*499

# %%
df.head()
# Out:
#           Word                                Definition Date  \
# 0      abandon  leave someone who needs or counts on you  NaT
# 1        Abate        become less in amount or intensity  NaT
# 2     abdicate      give up power, duties or obligations  NaT
# 3  abduct (v.)                                to kidnap   NaT
# 4   abase (v.)                 to lower, demean, degrade  NaT
#
#    Consecutive Right  Card Used
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN

# %%
df['Date'].isnull().sum()
# Out:
# 499

# %%
df['Date'] = df['Date'].astype('str')

# %%
df['Date'] = [np.nan]*499

# %%
df.to_csv('isee_csv.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of                Word                                Definition  Date  \
# 0           abandon  leave someone who needs or counts on you   NaN
# 1             Abate        become less in amount or intensity   NaN
# 2          abdicate      give up power, duties or obligations   NaN
# 3       abduct (v.)                                to kidnap    NaN
# 4        abase (v.)                 to lower, demean, degrade   NaN
# ..              ...                                       ...   ...
# 494        wax (v.)   to increase gradually in size or degree   NaN
# 495    weather (v.)       to withstand or survive a situation   NaN
# 496       whet (v.)              to make more keen, stimulate   NaN
# 497  winsome (adj.)                      charming, attractive   NaN
# 498  Zeitgeist (n.)                      the spirit of the ti   NaN
#
#      Consecutive Right  Card Used
# 0                  NaN        NaN
# 1                  NaN        NaN
# 2                  NaN        NaN
# 3                  NaN        NaN
# 4                  NaN        NaN
# ..                 ...        ...
# 494                NaN        NaN
# 495                NaN        NaN
# 496                NaN        NaN
# 497                NaN        NaN
# 498                NaN        NaN
#
# [499 rows x 5 columns]>

# %%
df_today = df.loc[df['Date'] < '2022-11-11']

# %%
date.today()
# Out:
# datetime.date(2022, 10, 26)

# %%
df['Date'] = pd.to_datetime(df["Date"]).dt.date

# %%
type(date.today())
# Out:
# datetime.date

# %%
type(df.at[311,'Date'])
# Out:
# pandas._libs.tslibs.nattype.NaTType

# %%
df['Date'] < pd.to_datetime(date.today())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# Name: Date, Length: 499, dtype: bool

# %%
df = pd.read_csv('isee_csv.csv')
df.head()
# Out:
#    Unnamed: 0         Word                                Definition  Date  \
# 0           0      abandon  leave someone who needs or counts on you   NaN
# 1           1        Abate        become less in amount or intensity   NaN
# 2           2     abdicate      give up power, duties or obligations   NaN
# 3           3  abduct (v.)                                to kidnap    NaN
# 4           4   abase (v.)                 to lower, demean, degrade   NaN
#
#    Consecutive Right  Card Used
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#           Word                                Definition  Date  \
# 0      abandon  leave someone who needs or counts on you   NaN
# 1        Abate        become less in amount or intensity   NaN
# 2     abdicate      give up power, duties or obligations   NaN
# 3  abduct (v.)                                to kidnap    NaN
# 4   abase (v.)                 to lower, demean, degrade   NaN
#
#    Consecutive Right  Card Used
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN

# %%
df.to_csv('isee_csv.csv', index = False)
